# %%
import numpy as np
import pandas as pd
from pylab import *

# %%
testing_phase1 = "./dataSets/testing_phase1/"
training = "./dataSets/training/"

# %%
date_time_format = "%Y-%m-%d %H:%M:%S"

table3 = pd.read_csv("./dataSets/training/links (table 3).csv")
table4= pd.read_csv("./dataSets/training/routes (table 4).csv")
table5= pd.read_csv("./dataSets/training/trajectories(table 5)_training.csv")
table6= pd.read_csv("./dataSets/training/volume(table 6)_training.csv")
table7= pd.read_csv("./dataSets/training/weather (table 7)_training.csv")

table5['starting_time'] = pd.to_datetime(table5['starting_time'], format=date_time_format)

# %%
table5.travel_seq[0]
# Out:
# '105#2016-07-19 00:14:24#9.56;100#2016-07-19 00:14:34#6.75;111#2016-07-19 00:14:41#13.00;103#2016-07-19 00:14:54#7.47;122#2016-07-19 00:15:02#32.85'

# %%
subtable = table5[table5.intersection_id == "A"]
plot(subtable.index,subtable['travel_time'] )
show()

# %%
subtable = table5[table5.intersection_id == "B"]
plot(subtable.index,subtable['travel_time'] )
show()

# %%
subtable = table5[table5.intersection_id == "C"]
plot(subtable.index,subtable['travel_time'] )
show()
